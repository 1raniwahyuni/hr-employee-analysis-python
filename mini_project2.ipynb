# %% [markdown]
# # Mini Project 2

# %% [markdown]
# #### Data Dictionary
#
# - **Age** : Age of the employee.
# - **Attrition** : Whether the employee left in the previous year or not.
# - **BusinessTravel** : How frequently the employees travelled for business purposes in the last year.
# - **Department** : Department in company.
# - **DistanceFromHome** : Distance from home in (km).
# - **Education** : Education Level.
#     - 1 : 'Below College'
#     - 2 : 'College'
#     - 3 : 'Bachelor'
#     - 4 : 'Master'
#     - 5 : 'Doctor'
# - **EducationField** : Field of education.
# - **EmployeeCount** : Employee count.
# - **EmployeeNumber** : Employee number/id.
# - **EnvironmentSatisfaction** : Work Environment Satisfaction Level.
#     - 1 'Low'
#     - 2 'Medium'
#     - 3 'High'
#     - 4 'Very High'
# - **Gender** : Gender of employee.
# - **JobInvolvement** : Job Involvement Level.
#     - 1 : 'Low'
#     - 2 : 'Medium'
#     - 3 : 'High'
#     - 4 : 'Very High'
# - **JobLevel** : Job level at company on a scale of 1 to 5.
# - **JobRole** : Name of job role in company.
# - **JobSatisfaction** : Job Satisfaction Level
#     - 1 : 'Low'
#     - 2 : 'Medium'
#     - 3 : 'High'
#     - 4 : 'Very High'
# - **MaritalStatus** : Marital status of the employee.
# - **MonthlyIncome** : Monthly income in rupees per month.
# - **NumCompaniesWorked** : Total number of companies the employee has worked for.
# - **Over18** : Whether the employee is above 18 years of age or not
# - **PercentSalaryHike** : Percent salary hike for last year.
# - **PerformanceRating** : Performance rating for last year.
#     - 1 : 'Low'
#     - 2 : 'Good'
#     - 3 : 'Excellent'
#     - 4 : 'Outstanding'
# - **RelationshipSatisfaction** : Relationship satisfaction level.
#     - 1 : 'Low'
#     - 2 : 'Medium'
#     - 3 : 'High'
#     - 4 : 'Very High'
# - **StandardHours** : Standard hours of work for the employee.
# - **StockOptionLevel** : Stock option level of the employee.
# - **TotalWorkingYears** : Total number of years the employee has worked so far.
# - **TrainingTimesLastYear** : Number of times training was conducted for this employee last year.
# - **WorkLifeBalance** : Work life balance level
#     - 1 : 'Bad'
#     - 2 : 'Good'
#     - 3 : 'Better'
#     - 4 : 'Best'
# - **YearsAtCompany** : Total number of years spent at the company by the employee.
# - **YearsSinceLastPromotion** : Number of years since last promotion.
# - **YearsWithCurrManager** : Number of years under current manager.

# %% [markdown]
# Data Source: https://www.kaggle.com/datasets/vjchoudhary7/hr-analytics-case-study/data

# %% [markdown]
# #### Step 1: Understanding the Dataset

# %%
# import library

# data wrangling
import numpy as np 
import pandas as pd

# data visualization
import matplotlib.pyplot as plt 
import seaborn as sns 

# filter warning
import warnings
warnings.filterwarnings('ignore')

# %%
# displays all existing columns
pd.options.display.max_columns = None

# %%
# load dataset 
df = pd.read_csv('D:\MYEDUSOLVE\File_Jupyter\Data_Analytics\Data\general_data.csv')
df.head(100)
# Out:
#     Age Attrition     BusinessTravel              Department  \
# 0    51        No      Travel_Rarely                   Sales
# 1    31       Yes  Travel_Frequently  Research & Development
# 2    32        No  Travel_Frequently  Research & Development
# 3    38        No         Non-Travel  Research & Development
# 4    32        No      Travel_Rarely  Research & Development
# ..  ...       ...                ...                     ...
# 95   37        No      Travel_Rarely  Research & Development
# 96   30        No         Non-Travel                   Sales
# 97   26        No      Travel_Rarely                   Sales
# 98   42        No      Travel_Rarely                   Sales
# 99   21       Yes  Travel_Frequently  Research & Development
#
#     DistanceFromHome  Education    EducationField  EmployeeCount  EmployeeID  \
# 0                  6          2     Life Sciences              1           1
# ...

# %%
# summary of dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4410 entries, 0 to 4409
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      4410 non-null   int64
#  1   Attrition                4410 non-null   object
#  2   BusinessTravel           4410 non-null   object
#  3   Department               4410 non-null   object
#  4   DistanceFromHome         4410 non-null   int64
#  5   Education                4410 non-null   int64
#  6   EducationField           4410 non-null   object
#  7   EmployeeCount            4410 non-null   int64
#  8   EmployeeID               4410 non-null   int64
#  9   Gender                   4410 non-null   object
#  10  JobLevel                 4410 non-null   int64
#  11  JobRole                  4410 non-null   object
#  12  MaritalStatus            4410 non-null   object
#  13  MonthlyIncome            4410 non-null   int64
# ...

# %%
df.isna().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeID                  0
# Gender                      0
# JobLevel                    0
# JobRole                     0
# MaritalStatus               0
# MonthlyIncome               0
# NumCompaniesWorked         19
# Over18                      0
# PercentSalaryHike           0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           9
# TrainingTimesLastYear       0
# YearsAtCompany              0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# dtype: int64

# %% [markdown]
# Dapat dilihat dari informasi di atas, bahwa kolom `NumCompaniesWorked` dan `TotalWorkingYears` terdapat missing value. Namun hanya sejumlah kecil dari keseluruhan jumlah data sehingga seharusnya tidak akan memengaruhi hasil analisis.

# %% [markdown]
# #### Step 2: Data Cleansing

# %%
# Replaces the value True with 1 and False with 0
df['Attrition'] = df['Attrition'].replace({'Yes': 1, 'No': 0}).fillna(0).astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4410 entries, 0 to 4409
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      4410 non-null   int64
#  1   Attrition                4410 non-null   int32
#  2   BusinessTravel           4410 non-null   object
#  3   Department               4410 non-null   object
#  4   DistanceFromHome         4410 non-null   int64
#  5   Education                4410 non-null   int64
#  6   EducationField           4410 non-null   object
#  7   EmployeeCount            4410 non-null   int64
#  8   EmployeeID               4410 non-null   int64
#  9   Gender                   4410 non-null   object
#  10  JobLevel                 4410 non-null   int64
#  11  JobRole                  4410 non-null   object
#  12  MaritalStatus            4410 non-null   object
#  13  MonthlyIncome            4410 non-null   int64
# ...

# %% [markdown]
# Tipe data kolom `Attrition` sudah diubah dari object menjadi integer (numerik) untuk memudahkan analisis.

# %%
# number of elements before dropping missing value
df.shape
# Out:
# (4410, 24)

# %% [markdown]
# Jumlah elemen (baris,kolom) sebelum penghapusan data yang hilang adalah 4410 baris dan 24 kolom

# %%
# listwise dropping (handling missing value)
df = df.dropna()

# %%
df=df.drop(columns=['EmployeeCount', 'StandardHours','EmployeeID'])

# %%
# number of elements after dropping missing value
df.shape
# Out:
# (4382, 21)

# %% [markdown]
# Jumlah elemen (baris,kolom) setelah penghapusan data yang hilang adalah 4328 baris dan 24 kolom. Perubahan jumlah baris ini mengindikasikan bahwa ada beberapa missing value dalam satu baris

# %%
# reset index
df = df.reset_index(drop = True)

# %%
df.isna().sum()
# Out:
# Age                        0
# Attrition                  0
# BusinessTravel             0
# Department                 0
# DistanceFromHome           0
# Education                  0
# EducationField             0
# Gender                     0
# JobLevel                   0
# JobRole                    0
# MaritalStatus              0
# MonthlyIncome              0
# NumCompaniesWorked         0
# Over18                     0
# PercentSalaryHike          0
# StockOptionLevel           0
# TotalWorkingYears          0
# TrainingTimesLastYear      0
# YearsAtCompany             0
# YearsSinceLastPromotion    0
# YearsWithCurrManager       0
# dtype: int64

# %% [markdown]
# Dapat dilihat dari informasi di atas bahwa missing value sudah bersih dari semua kolom yang ada.

# %%
# separates data of object type
df_num = df.select_dtypes(exclude=['object','category'])

# %%
# function to find outliers using numpy
def find_outlier(data):
    Q1 = np.quantile(data, .25)
    Q2 = np.quantile(data, .50)
    Q3 = np.quantile(data, .75)

    IQR = (Q3 - Q1) * 1.5
    lower_limit = Q1 - IQR
    upper_limit = Q3 + IQR

    outlier = ''
    for i in range(len(data)):
        if data[i] > upper_limit:
            outlier = outlier + str(data[i]) + ', '
        elif data[i] < lower_limit:
            outlier = outlier + str(data[i]) + ', '
    return outlier

# %%
# detect outlier from each column usinng loop
for i in df_num:
    print(f'Outlier Detected {i}:', 
          (len(find_outlier(df_num[i].sort_values().values.tolist()))))
# Out:
# Outlier Detected Age: 0
# Outlier Detected Attrition: 2115
# Outlier Detected DistanceFromHome: 0
# Outlier Detected Education: 0
# Outlier Detected JobLevel: 0
# Outlier Detected MonthlyIncome: 2728
# Outlier Detected NumCompaniesWorked: 780
# Outlier Detected PercentSalaryHike: 0
# Outlier Detected StockOptionLevel: 762
# Outlier Detected TotalWorkingYears: 1134
# Outlier Detected TrainingTimesLastYear: 2130
# Outlier Detected YearsAtCompany: 1236
# Outlier Detected YearsSinceLastPromotion: 1175
# Outlier Detected YearsWithCurrManager: 168

# %% [markdown]
# Berdasarkan informasi di atas, outlier yang ada cukup besar dari beberapa kolom yang jumlahnya hampir setengahnya dari jumlah keseluruhan data. Namun, outlier ini tidak akan mengganggu proses analisis karena tidak memengaruhi hasil analisis secara signifikan dan tidak memengaruhi asumsi yang dibuat dari analisis.

# %% [markdown]
# #### Step 3: Descriptive Analysis

# %%
df.describe()
# Out:
#                Age    Attrition  DistanceFromHome    Education     JobLevel  \
# count  4382.000000  4382.000000       4382.000000  4382.000000  4382.000000
# mean     36.933364     0.160885          9.198996     2.912369     2.063898
# std       9.137272     0.367467          8.105396     1.024728     1.106115
# min      18.000000     0.000000          1.000000     1.000000     1.000000
# 25%      30.000000     0.000000          2.000000     2.000000     1.000000
# 50%      36.000000     0.000000          7.000000     3.000000     2.000000
# 75%      43.000000     0.000000         14.000000     4.000000     3.000000
# max      60.000000     1.000000         29.000000     5.000000     5.000000
#
#        MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  StockOptionLevel  \
# count    4382.000000         4382.000000        4382.000000       4382.000000
# mean    65061.702419            2.693291          15.210634          0.794614
# ...

# %% [markdown]
# The information above is a table about the descriptive statistics of each column of numeric type, namely **Age**, **DistanceFromHome**, **Education**, to the column **YearsWithCurrManager**.
# - The average age of employees working in the company is 36 years old, the lowest age of employees working is 18 years old and the highest age is 60 years old.
# - The average distance from the employee's home to the office is 9 km, the closest distance is 1 km and the farthest is 29 km.
# - The average monthly income of employees is 65061 (dollars), the lowest is 10090 (dollars) and the highest is 199990 (dollars).
# - The average work experience of employees is 2 companies, the lowest is 0 which indicates this company is the first experience and the highest is 9 companies which indicates this company is the 10th company the employee has worked for.
# - The average percent increase in employee salary is 15 percent, the lowest is 11 percent and the highest is 25 percent.
# - The average work experience of employees is 11 years, the lowest is 0 years (fresh graduate) and the highest is 40 years.
# - The average employee works at XYZ company for 7 years, the longest reaching 40 years.

# %%
df.describe(include='object')
# Out:
#        BusinessTravel              Department EducationField Gender  \
# count            4382                    4382           4382   4382
# unique              3                       3              6      2
# top     Travel_Rarely  Research & Development  Life Sciences   Male
# freq             3109                    2865           1806   2626
#
#                 JobRole MaritalStatus Over18
# count              4382          4382   4382
# unique                9             3      1
# top     Sales Executive       Married      Y
# freq                975          2007   4382

# %% [markdown]
# The information above is a table about the descriptive statistics of each column of categorical type, namely **Attrition**, **BusinessTravel** to the column **Over18**
# - Most of the employees choose to stay at XYZ company.
# - Most employees rarely mobilize for work purposes.
# - The department that has a large number of employees is Research & Development.
# - Most of the employees are from the Life Science field.
# - Male employees outnumber female employees.
# - Most employee roles are in the Sales Executive position.
# - Most employees are married.
# - And all employees are over 18 years old.

# %%
# show distribution for each column
for col in df_num:
  plt.figure(figsize=(8,4))
  sns.distplot(df[col])
  plt.axvline(df[col].mean(), color ='r')
  plt.axvline(df[col].median(), color ='g')
  plt.axvline(df[col].mean() - df[col].std(), color ='y')
  plt.axvline(df[col].mean() + df[col].std(), color ='y')
  plt.show()

# %%
df.select_dtypes(exclude='object').skew()
# Out:
# Age                        0.413048
# Attrition                  1.846529
# DistanceFromHome           0.955517
# Education                 -0.288977
# JobLevel                   1.021797
# MonthlyIncome              1.367457
# NumCompaniesWorked         1.029174
# PercentSalaryHike          0.819510
# StockOptionLevel           0.967263
# TotalWorkingYears          1.115419
# TrainingTimesLastYear      0.551818
# YearsAtCompany             1.764619
# YearsSinceLastPromotion    1.980992
# YearsWithCurrManager       0.834277
# dtype: float64

# %% [markdown]
# Berdasarkan distribusi di atas, garis merah adalah garis rata-rata (mean), garis hijau adalah median, dan garis kuning adalah standar deviasi.
# - Kolom **Age, DistanceFromHome, Attrition, JobLevel, MonthlyIncome, NumCompaniesWorked, PercentSalaryHike, TotalWorkingYear, YearsAtCompany, YearsSinceLastPromotion, YearsWithCurrManager, StockOptionLevel, TrainingTimeLastYear** adalah kolom yang bertipe **Positif Skewed Distribution** yang mengindikasikan distribusinya adalah **Right Tailed**.
# - Sedangkan kolom **Education** adalah kolom yang bertipe Negative Skewed Distribution yang mengindikasikan distribusinya adalah **Left Tailed**.

# %%
#correlation matrix between numerical columns
df_num = df.select_dtypes(exclude=['object', 'category'])
corr_matrix = df_num.corr()
corr_matrix
# Out:
#                               Age  Attrition  DistanceFromHome  Education  \
# Age                      1.000000  -0.158399          0.007376  -0.033900
# Attrition               -0.158399   1.000000         -0.009449  -0.017106
# DistanceFromHome         0.007376  -0.009449          1.000000  -0.007491
# Education               -0.033900  -0.017106         -0.007491   1.000000
# JobLevel                -0.001137  -0.012382         -0.039990   0.045822
# MonthlyIncome           -0.045163  -0.030160         -0.022757   0.007289
# NumCompaniesWorked       0.299527   0.042831         -0.014449  -0.016210
# PercentSalaryHike       -0.032561   0.033153          0.037720  -0.041054
# StockOptionLevel        -0.031504  -0.008164          0.009353   0.002386
# TotalWorkingYears        0.680037  -0.169670          0.009574  -0.009228
# TrainingTimesLastYear   -0.028962  -0.047586         -0.008957   0.009939
# YearsAtCompany           0.311281  -0.133003          0.030746   0.005997
# ...

# %%
#basic heatmap using seaborn
plt.figure(figsize=(15,5))

sns.heatmap(corr_matrix, annot=True, linewidths=1,
            linecolor='black', fmt='.2f',
            cbar_kws={'label': 'Correlation Coefficient'})

plt.title('Customized Heat Map of Correlations (Seaborn)')
plt.show()

# %% [markdown]
# Berdasarkan Matriks Korelasi di atas terdapat beberapa korelasi/hubungan antara kolom satu sama lain.
# - Kolom TotalWorkingYears berkorelasi kuat dengan kolom Age dan YearsAtCompany. Namun, berkorelasi cukup dengan YearSsinceLastPromotion, dan YearsWithCurrManager.
# - Kolom YearsAtCompany berkorelasi kuat dengan kolom YearSsinceLastPromotion, YearsWWithCurrManager dan TotalWorkingYears. Namun, berkorelasi lemah dengan kolom Age.
# - Kolom YearSsinceLastPromotion berkorelasi kuat dengan kolom YearsAtCompany. Namun berkorelasi cukup kuat dengan kolom YearsWWithCurrManager dan TotalWorkingYears.
# - Kolom YearsWWithCurrManager berkorelasi kuat dengan kolom YearsAtCompany. Namun berkorelasi cukup kuat dengan kolom YearSsinceLastPromotion dan TotalWorkingYears.

# %% [markdown]
# #### Insight

# %%
# average monthly salary by job role
plt.figure(figsize=(11,6))
ax = sns.barplot(data=df, x='JobRole', y='MonthlyIncome', estimator='mean', palette='Blues', )
plt.title('Average Monthly Income by Job Role')

# Add numerical labels above each bar
for p in ax.patches:
    ax.annotate(f'{p.get_height():.1f}',
                (p.get_x() + p.get_width()/2, p.get_height()),
                textcoords="offset points", xytext=(0, 30),  # 5 points above the bar
                ha='center', fontsize=10, color='black')
plt.xticks(rotation=45, ha='right')
plt.ylim(0, 75000 * 1.1)
plt.show()

# %% [markdown]
# Berdasarkan gambar tersebut, menunjukkan bahwa job role 'Manufacturing Directur' merupakan posisi yang paling banyak memperoleh income tiap bulannya yaitu dengan rata-rata sebesar 69245,6. Sedangkan jobrole 'Human Resources' merupakan posisi yang paling rendah memperoleh income tiap bulannya yaitu dengan rata-rata sebesar 5828,1

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='JobRole', hue='Education', palette='Set3')

plt.title('Education Background by Job Role')
plt.xlabel('Job Role')
plt.ylabel('Number of Employees')
plt.xticks(rotation=45, ha='right')
plt.grid(linestyle = '--', alpha=0.8) # grid
plt.ylim(0, 400 * 1.1)

handles, labels = plt.gca().get_legend_handles_labels()

plt.legend(handles=handles, labels=['Below College', 'College', 'Bachelor', 'Master', 'Doctor'], title='Education Level')
plt.show()

# %% [markdown]
# Berdasarkan gambar tersebut, menunjukkan bahwa latar belakang pendidikan pada tiap jobrole di perusahaan XYZ paling banyak adalah berpendidikan 'bachelor'  dan paling sedikit adalah berpendidikan 'doctor'

# %%
df
# Out:
#       Age  Attrition     BusinessTravel              Department  \
# 0      51          0      Travel_Rarely                   Sales
# 1      31          1  Travel_Frequently  Research & Development
# 2      32          0  Travel_Frequently  Research & Development
# 3      38          0         Non-Travel  Research & Development
# 4      32          0      Travel_Rarely  Research & Development
# ...   ...        ...                ...                     ...
# 4377   29          0      Travel_Rarely                   Sales
# 4378   42          0      Travel_Rarely  Research & Development
# 4379   29          0      Travel_Rarely  Research & Development
# 4380   25          0      Travel_Rarely  Research & Development
# 4381   42          0      Travel_Rarely                   Sales
#
#       DistanceFromHome  Education EducationField  Gender  JobLevel  \
# 0                    6          2  Life Sciences  Female         1
# ...

# %%
# Job Role
df['JobRole'].value_counts()
# Out:
# JobRole
# Sales Executive              975
# Research Scientist           872
# Laboratory Technician        773
# Manufacturing Director       429
# Healthcare Representative    389
# Manager                      305
# Sales Representative         246
# Research Director            237
# Human Resources              156
# Name: count, dtype: int64

# %%
attrition_count_by_role = df[df['Attrition'] == 1]['JobRole'].value_counts()

plt.figure(figsize=(8, 6))

# Sort the Series by count in descending order
attrition_count_by_role_sorted = attrition_count_by_role.sort_values(ascending=False)

# Create a bar chart
sns.barplot(x=attrition_count_by_role_sorted.index, y=attrition_count_by_role_sorted.values)

plt.xlabel('Job Role')
plt.ylabel('Number of Attritions')
plt.title('Number of Attritions by Job Role')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust spacing for clarity
plt.show()

# %% [markdown]
# Berdasarkan visualisasi tersebut, posisi Sales Executive menjadi total jumlah terbesar pengurangan jumlah karyawan sebanyak 975 karyawan dan yang paling sedikit dari posisi Human Resource dengan jumlah 156 jumlah karyawan yang keluar.

# %%
df['Department'].value_counts()
# Out:
# Department
# Research & Development    2865
# Sales                     1330
# Human Resources            187
# Name: count, dtype: int64

# %%
attrition_count_by_department = df[df['Attrition'] == 1]['Department'].value_counts()

plt.figure(figsize=(5, 5))

# Sort the Series by count in descending order
attrition_count_by_department_sorted = attrition_count_by_department.sort_values(ascending=False)

# Create a bar chart
sns.barplot(x=attrition_count_by_department_sorted.index, y=attrition_count_by_department_sorted.values)

plt.xlabel('Department')
plt.ylabel('Number of Attritions')
plt.title('Number of Attritions by Department')
plt.xticks(ha='center')  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust spacing for clarity
plt.show()

# %% [markdown]
# Berdasarkan visualisasi di atas, Department Research and Development menjadi department yang paling banyak total jumlah penguarangan karyawannya yaitu sebanyak 2865 karyawan, disusul dengan department Sales dengan jumlah 1330 karyawan, dan Human Resource menjadi department yang paling sedikit jumlah total pengurangan karyawannya yaitu sebanyak 187 karyawan.

# %% [markdown]
# ![image.png](attachment:image.png)
